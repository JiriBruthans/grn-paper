# %%
from joblib import Parallel, delayed
from tqdm.notebook import tqdm

import sys
import pickle
import numpy as np
import pandas as pd
import networkx as nx
import scipy
from itertools import combinations

# %%
sys.path.insert(0, "src")

from grn import grn

np.random.seed(5)

# %%
G = grn().add_structure(
    n=256,
    k=1,
    alpha=1e-99,
    beta=0.75,       # 1 - 1/r
    gamma=0.25,      # 1/r
    kappa=10,        # --w
    delta_in=100,
    delta_out=1,
)

# %%
G.simulate_rna(
    s=1e-4,
    dt=1e-2,
    tmax=20000,
    burnin=5000,
    tol=1e-3,
    save=True,
)
# Out:
# array([[0.40134766, 0.52113436, 0.41345122, 0.55423591, 0.24940203,
#         0.00824444, 0.7499939 , 0.05158365, 0.34878561, 0.24131589,
#         0.10210803, 0.42921168, 0.43213425, 0.17597388, 0.50327465,
#         0.0090051 , 0.84216039, 0.43807547, 0.08892712, 0.00517759,
#         0.15249503, 0.00826165, 0.03296733, 0.35410256, 0.025503  ,
#         0.02003108, 0.62896421, 0.09378358, 0.37294875, 0.01978424,
#         0.26145216, 0.52016119, 0.55319635, 0.59044607, 0.34743717,
#         0.21467853, 0.80743297, 0.2937654 , 0.07668098, 0.0138034 ,
#         0.41741296, 0.0071455 , 0.32524356, 0.38381767, 0.07250683,
#         0.44120831, 0.20507611, 0.00378403, 0.0889725 , 0.05392258,
#         0.02707397, 0.19675887, 0.96476643, 0.57437545, 0.02445512,
#         0.83692191, 0.02542303, 0.48768259, 0.22263909, 0.0725727 ,
#         0.06521748, 0.82519536, 0.1272956 , 0.20865251, 0.25144698,
#         0.28727185, 0.09699723, 0.21344278, 0.0803279 , 0.04291328,
#         0.29524823, 0.35575755, 0.13498879, 0.01551461, 0.11733488,
#         0.35908484, 0.53275489, 0.33426452, 0.20150946, 0.09578871,
#         0.59251569, 0.95407999, 0.46818069, 0.13601863, 0.22884787,
#         0.16254994, 0.2532787 , 0.44253772, 0.87997237, 0.50627013,
#         0.38803581, 0.02612441, 0.03686745, 1.0042919 , 0.03359565,
#         0.15814613, 0.37216284, 0.10748189, 0.06850429, 0.10586803,
#         0.73829496, 0.12035743, 0.22518376, 0.51625206, 0.42684779,
#         0.24004437, 0.73990556, 0.43123084, 0.56504032, 0.01427539,
#         1.08021858, 0.16422087, 0.21350367, 0.11681341, 0.06693858,
#         0.07622553, 0.33354196, 0.21147277, 0.17132714, 0.30684252,
#         0.48156316, 0.03603277, 0.14270484, 0.11872336, 0.05688907,
#         0.20775283, 0.10507527, 0.13152793, 0.69751983, 0.07786895,
#         0.98841032, 0.10888001, 0.37456016, 0.04608685, 0.01854086,
#         0.33677028, 0.13229909, 0.04737469, 0.27713091, 0.02618686,
#         0.22571068, 0.13009735, 0.23193745, 0.18633523, 0.12502692,
#         0.47396813, 0.07523917, 0.00549953, 0.5804874 , 0.10295894,
#         0.8465393 , 0.25768409, 0.6753589 , 0.1297012 , 0.47897156,
#         0.5394125 , 0.32422184, 0.19082425, 0.10037311, 0.2276039 ,
#         0.45064012, 0.03936776, 0.05639478, 0.05700617, 0.44232504,
#         0.09327925, 0.30724314, 0.08045275, 0.78144731, 0.19494991,
#         0.58204807, 0.00250805, 0.35041942, 0.0372133 , 0.38462403,
#         0.70070228, 0.10664936, 0.07922661, 0.09691924, 0.11670478,
#         0.08836538, 0.11912294, 0.65605108, 0.01016181, 0.03990721,
#         0.03098626, 0.10908321, 0.28718492, 0.15353243, 0.03394761,
#         0.79961257, 0.94638614, 0.10207129, 0.16354977, 0.06842987,
#         0.06544351, 0.32271816, 0.15598402, 0.13673451, 0.11604022,
#         0.20380373, 0.17208469, 0.13284785, 0.01006259, 0.34196103,
#         0.16535081, 0.23394754, 0.17022728, 0.12930669, 0.11734679,
#         0.1513602 , 0.11681774, 0.07060387, 0.28363188, 0.26965202,
#         0.07120765, 0.58881909, 0.37299857, 0.16221706, 0.22200711,
#         0.76493457, 0.2840468 , 0.06508388, 0.26549185, 0.08821342,
#         0.4076829 , 0.04435685, 0.41757469, 0.27769578, 0.47545563,
#         0.51148143, 0.03908757, 0.20484829, 0.1837031 , 0.08042213,
#         0.48760275, 0.73464011, 0.08875153, 0.19680711, 0.1065496 ,
#         0.1089437 , 0.05269275, 0.20428085, 0.04259784, 0.59298169,
#         0.78659928, 0.16800453, 0.04476488, 0.71109706, 0.16089273,
#         0.12294879, 0.50252986, 0.29637737, 0.72159394, 0.10092961,
#         0.31266398]])

# %%
wt_expression = np.asarray(G.rna).flatten()

wt_df = pd.DataFrame(
    [wt_expression],
    index=["WT"],
    columns=[f"gene_{i}" for i in range(G.n)],
)

wt_df.to_csv("wt_expression.csv")

print("Converged:", G.converged)
print("Expression shape:", wt_expression.shape)
display(wt_df)
# Out:
# Converged: True
# Expression shape: (256,)
#       gene_0    gene_1    gene_2    gene_3    gene_4    gene_5    gene_6  \
# WT  0.401348  0.521134  0.413451  0.554236  0.249402  0.008244  0.749994
#
#       gene_7    gene_8    gene_9  ...  gene_246  gene_247  gene_248  gene_249  \
# WT  0.051584  0.348786  0.241316  ...  0.168005  0.044765  0.711097  0.160893
#
#     gene_250  gene_251  gene_252  gene_253  gene_254  gene_255
# WT  0.122949   0.50253  0.296377  0.721594   0.10093  0.312664
#
# [1 rows x 256 columns]

# %%
B = G.beta 
x = G.rna.flatten()
l = G.l.flatten()
a = G.alpha.flatten()
    
# jacobian
sig = scipy.special.expit(a + B.T@x.reshape(-1,1))
#sig = (l*x)
A = B.T * (sig * (1 - sig)) - np.diag(l)
evals, evecs = np.linalg.eig(A)
       
# result
stable = all(evals.real < 0)
print(stable)
# Out:
# True

# %%
ko_expression = np.zeros((G.n, G.n))
ko_logfc = np.zeros((G.n, G.n))
ko_convergence = {}

for gene in tqdm(range(G.n), desc="Simulating single-gene KOs"):
    
    result = G.ko_nodes(
        genes=[gene],
        stats=("new_rna", 'logfc', 'convergence'),
        s=0,
        dt=1e-2,
        tmax=20000,
        burnin=5000,
        tol=1e-3,
    )
    
    ko_expression[gene, :] = result["new_rna"].flatten()
    ko_logfc[gene, :] = result["logfc"].flatten()
    ko_convergence[gene] = result['convergence']

# Rows = perturbations
# Columns = measured genes
ko_df = pd.DataFrame(
    ko_expression,
    index=[f"KO_{i}" for i in range(G.n)],
    columns=[f"gene_{i}" for i in range(G.n)],
)

fc_ko_df = pd.DataFrame(
    ko_logfc,
    index=[f"KO_{i}" for i in range(G.n)],
    columns=[f"gene_{i}" for i in range(G.n)],
)




# Also save one convenient combined WT + KO matrix
expression_df = pd.concat([wt_df, ko_df])

print("KO matrix shape:", ko_df.shape)
print("Combined matrix shape:", expression_df.shape)

display(expression_df.head())
# Out:
# Simulating single-gene KOs:   0%|          | 0/256 [00:00<?, ?it/s]

# %%
#ko_convergence is true for all

# %%
pairs = np.array(
    list(combinations(range(G.n), 2)),
    dtype=np.int32
)

print("Number of genes:", G.n)
print("Number of double perturbations:", len(pairs))
# For n=200: 19,900
# Out:
# Number of genes: 256
# Number of double perturbations: 32640

# %%
subset_pairs = pairs

# %%
n_jobs = 64

def run_double_ko(pair):
    a, b = pair

    result = G.ko_nodes(
        genes=[a, b],
        stats=("new_rna", "logfc", 'convergence'),
        s=1e-4,
        dt=1e-2,
        tmax=20000,
        burnin=5000,
        tol=1e-3,
    )

    return (
        np.asarray(result["new_rna"]).flatten(),
        np.asarray(result["logfc"]).flatten(),
        np.asarray(result['convergence'])
    )


results = Parallel(
    n_jobs=64,
    pre_dispatch="n_jobs",
    prefer="processes",
    verbose=10,
)(
    delayed(run_double_ko)(pair)
    for pair in pairs
)

double_expression = np.asarray(
    [r[0] for r in results],
    dtype=np.float32
)

double_logfc = np.asarray(
    [r[1] for r in results],
    dtype=np.float32
)
double_convergence = np.asarray(
    [r[2] for r in results],
    dtype=np.float32
)

print("double_expression:", double_expression.shape)
print("double_logfc:", double_logfc.shape)
# Out:
# [Parallel(n_jobs=64)]: Using backend LokyBackend with 64 concurrent workers.
# [Parallel(n_jobs=64)]: Done   8 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=64)]: Done  21 tasks      | elapsed:    3.9s
# [Parallel(n_jobs=64)]: Done  34 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=64)]: Done  49 tasks      | elapsed:    4.4s
# [Parallel(n_jobs=64)]: Done  64 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=64)]: Done  81 tasks      | elapsed:    4.8s
# [Parallel(n_jobs=64)]: Done  98 tasks      | elapsed:    5.2s
# [Parallel(n_jobs=64)]: Done 117 tasks      | elapsed:    5.9s
# [Parallel(n_jobs=64)]: Done 136 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=64)]: Done 157 tasks      | elapsed:    7.1s
# [Parallel(n_jobs=64)]: Done 178 tasks      | elapsed:    7.7s
# [Parallel(n_jobs=64)]: Done 201 tasks      | elapsed:    8.4s
# [Parallel(n_jobs=64)]: Done 224 tasks      | elapsed:    8.9s
# [Parallel(n_jobs=64)]: Done 249 tasks      | elapsed:    9.6s
# [Parallel(n_jobs=64)]: Done 274 tasks      | elapsed:   10.4s
# [Parallel(n_jobs=64)]: Done 301 tasks      | elapsed:   11.0s
# [Parallel(n_jobs=64)]: Done 328 tasks      | elapsed:   11.7s
# [Parallel(n_jobs=64)]: Done 357 tasks      | elapsed:   12.5s
# [Parallel(n_jobs=64)]: Done 386 tasks      | elapsed:   13.2s
# [Parallel(n_jobs=64)]: Done 417 tasks      | elapsed:   14.1s
# [Parallel(n_jobs=64)]: Done 448 tasks      | elapsed:   14.9s
# [Parallel(n_jobs=64)]: Done 481 tasks      | elapsed:   15.7s
# [Parallel(n_jobs=64)]: Done 514 tasks      | elapsed:   16.3s
# [Parallel(n_jobs=64)]: Done 549 tasks      | elapsed:   17.2s
# [Parallel(n_jobs=64)]: Done 584 tasks      | elapsed:   18.1s
# [Parallel(n_jobs=64)]: Done 621 tasks      | elapsed:   19.1s
# [Parallel(n_jobs=64)]: Done 658 tasks      | elapsed:   20.1s
# [Parallel(n_jobs=64)]: Done 697 tasks      | elapsed:   21.0s
# [Parallel(n_jobs=64)]: Done 736 tasks      | elapsed:   22.1s
# [Parallel(n_jobs=64)]: Done 777 tasks      | elapsed:   23.1s
# [Parallel(n_jobs=64)]: Done 818 tasks      | elapsed:   24.2s
# [Parallel(n_jobs=64)]: Done 861 tasks      | elapsed:   25.5s
# [Parallel(n_jobs=64)]: Done 904 tasks      | elapsed:   26.6s
# [Parallel(n_jobs=64)]: Done 949 tasks      | elapsed:   27.9s
# [Parallel(n_jobs=64)]: Done 994 tasks      | elapsed:   29.0s
# [Parallel(n_jobs=64)]: Done 1041 tasks      | elapsed:   30.4s
# [Parallel(n_jobs=64)]: Done 1088 tasks      | elapsed:   31.7s
# [Parallel(n_jobs=64)]: Done 1137 tasks      | elapsed:   33.0s
# [Parallel(n_jobs=64)]: Done 1186 tasks      | elapsed:   34.3s
# [Parallel(n_jobs=64)]: Done 1237 tasks      | elapsed:   36.0s
# [Parallel(n_jobs=64)]: Done 1288 tasks      | elapsed:   37.3s
# [Parallel(n_jobs=64)]: Done 1341 tasks      | elapsed:   38.5s
# [Parallel(n_jobs=64)]: Done 1394 tasks      | elapsed:   40.0s
# [Parallel(n_jobs=64)]: Done 1449 tasks      | elapsed:   41.5s
# [Parallel(n_jobs=64)]: Done 1504 tasks      | elapsed:   42.9s
# [Parallel(n_jobs=64)]: Done 1561 tasks      | elapsed:   44.6s
# [Parallel(n_jobs=64)]: Done 1618 tasks      | elapsed:   46.1s
# [Parallel(n_jobs=64)]: Done 1677 tasks      | elapsed:   47.9s
# [Parallel(n_jobs=64)]: Done 1736 tasks      | elapsed:   49.4s
# [Parallel(n_jobs=64)]: Done 1797 tasks      | elapsed:   51.1s
# [Parallel(n_jobs=64)]: Done 1858 tasks      | elapsed:   52.8s
# [Parallel(n_jobs=64)]: Done 1921 tasks      | elapsed:   54.5s
# [Parallel(n_jobs=64)]: Done 1984 tasks      | elapsed:   56.2s
# [Parallel(n_jobs=64)]: Done 2049 tasks      | elapsed:   58.0s
# [Parallel(n_jobs=64)]: Done 2114 tasks      | elapsed:   59.9s
# [Parallel(n_jobs=64)]: Done 2181 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=64)]: Done 2248 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=64)]: Done 2317 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=64)]: Done 2386 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=64)]: Done 2457 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=64)]: Done 2528 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=64)]: Done 2601 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=64)]: Done 2674 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=64)]: Done 2749 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=64)]: Done 2824 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=64)]: Done 2901 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=64)]: Done 2978 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=64)]: Done 3057 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=64)]: Done 3136 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=64)]: Done 3217 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=64)]: Done 3298 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=64)]: Done 3381 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=64)]: Done 3464 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=64)]: Done 3549 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=64)]: Done 3634 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=64)]: Done 3721 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=64)]: Done 3808 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=64)]: Done 3897 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=64)]: Done 3986 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=64)]: Done 4077 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=64)]: Done 4168 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=64)]: Done 4261 tasks      | elapsed:  2.0min
# [Parallel(n_jobs=64)]: Done 4354 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=64)]: Done 4449 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=64)]: Done 4544 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=64)]: Done 4641 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=64)]: Done 4738 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=64)]: Done 4837 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=64)]: Done 4936 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=64)]: Done 5037 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=64)]: Done 5138 tasks      | elapsed:  2.4min
# [Parallel(n_jobs=64)]: Done 5241 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=64)]: Done 5344 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=64)]: Done 5449 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=64)]: Done 5554 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=64)]: Done 5661 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=64)]: Done 5768 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=64)]: Done 5877 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=64)]: Done 5986 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=64)]: Done 6097 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=64)]: Done 6208 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=64)]: Done 6321 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=64)]: Done 6434 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=64)]: Done 6549 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=64)]: Done 6664 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=64)]: Done 6781 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=64)]: Done 6898 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=64)]: Done 7017 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=64)]: Done 7136 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=64)]: Done 7257 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=64)]: Done 7378 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=64)]: Done 7501 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=64)]: Done 7624 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=64)]: Done 7749 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=64)]: Done 7874 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=64)]: Done 8001 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=64)]: Done 8128 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=64)]: Done 8257 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=64)]: Done 8386 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=64)]: Done 8517 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=64)]: Done 8648 tasks      | elapsed:  4.1min
# [Parallel(n_jobs=64)]: Done 8781 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=64)]: Done 8914 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=64)]: Done 9049 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=64)]: Done 9184 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=64)]: Done 9321 tasks      | elapsed:  4.4min
# [Parallel(n_jobs=64)]: Done 9458 tasks      | elapsed:  4.5min
# [Parallel(n_jobs=64)]: Done 9597 tasks      | elapsed:  4.5min
# [Parallel(n_jobs=64)]: Done 9736 tasks      | elapsed:  4.6min
# [Parallel(n_jobs=64)]: Done 9877 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=64)]: Done 10018 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=64)]: Done 10161 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=64)]: Done 10304 tasks      | elapsed:  4.9min
# [Parallel(n_jobs=64)]: Done 10449 tasks      | elapsed:  4.9min
# [Parallel(n_jobs=64)]: Done 10594 tasks      | elapsed:  5.0min
# [Parallel(n_jobs=64)]: Done 10741 tasks      | elapsed:  5.1min
# [Parallel(n_jobs=64)]: Done 10888 tasks      | elapsed:  5.2min
# [Parallel(n_jobs=64)]: Done 11037 tasks      | elapsed:  5.2min
# [Parallel(n_jobs=64)]: Done 11186 tasks      | elapsed:  5.3min
# [Parallel(n_jobs=64)]: Done 11337 tasks      | elapsed:  5.4min
# [Parallel(n_jobs=64)]: Done 11488 tasks      | elapsed:  5.4min
# [Parallel(n_jobs=64)]: Done 11641 tasks      | elapsed:  5.5min
# [Parallel(n_jobs=64)]: Done 11794 tasks      | elapsed:  5.6min
# [Parallel(n_jobs=64)]: Done 11949 tasks      | elapsed:  5.7min
# [Parallel(n_jobs=64)]: Done 12104 tasks      | elapsed:  5.7min
# [Parallel(n_jobs=64)]: Done 12261 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=64)]: Done 12418 tasks      | elapsed:  5.9min
# [Parallel(n_jobs=64)]: Done 12577 tasks      | elapsed:  6.0min
# [Parallel(n_jobs=64)]: Done 12736 tasks      | elapsed:  6.0min
# [Parallel(n_jobs=64)]: Done 12897 tasks      | elapsed:  6.1min
# [Parallel(n_jobs=64)]: Done 13058 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=64)]: Done 13221 tasks      | elapsed:  6.3min
# [Parallel(n_jobs=64)]: Done 13384 tasks      | elapsed:  6.4min
# [Parallel(n_jobs=64)]: Done 13549 tasks      | elapsed:  6.4min
# [Parallel(n_jobs=64)]: Done 13714 tasks      | elapsed:  6.5min
# [Parallel(n_jobs=64)]: Done 13881 tasks      | elapsed:  6.6min
# [Parallel(n_jobs=64)]: Done 14048 tasks      | elapsed:  6.7min
# [Parallel(n_jobs=64)]: Done 14217 tasks      | elapsed:  6.8min
# [Parallel(n_jobs=64)]: Done 14386 tasks      | elapsed:  6.8min
# [Parallel(n_jobs=64)]: Done 14557 tasks      | elapsed:  6.9min
# [Parallel(n_jobs=64)]: Done 14728 tasks      | elapsed:  7.0min
# [Parallel(n_jobs=64)]: Done 14901 tasks      | elapsed:  7.1min
# [Parallel(n_jobs=64)]: Done 15074 tasks      | elapsed:  7.2min
# [Parallel(n_jobs=64)]: Done 15249 tasks      | elapsed:  7.3min
# [Parallel(n_jobs=64)]: Done 15424 tasks      | elapsed:  7.3min
# [Parallel(n_jobs=64)]: Done 15601 tasks      | elapsed:  7.4min
# [Parallel(n_jobs=64)]: Done 15778 tasks      | elapsed:  7.5min
# [Parallel(n_jobs=64)]: Done 15957 tasks      | elapsed:  7.6min
# [Parallel(n_jobs=64)]: Done 16136 tasks      | elapsed:  7.7min
# [Parallel(n_jobs=64)]: Done 16317 tasks      | elapsed:  7.8min
# [Parallel(n_jobs=64)]: Done 16498 tasks      | elapsed:  7.9min
# [Parallel(n_jobs=64)]: Done 16681 tasks      | elapsed:  8.0min
# [Parallel(n_jobs=64)]: Done 16864 tasks      | elapsed:  8.0min
# [Parallel(n_jobs=64)]: Done 17049 tasks      | elapsed:  8.1min
# [Parallel(n_jobs=64)]: Done 17234 tasks      | elapsed:  8.2min
# [Parallel(n_jobs=64)]: Done 17421 tasks      | elapsed:  8.3min
# [Parallel(n_jobs=64)]: Done 17608 tasks      | elapsed:  8.4min
# [Parallel(n_jobs=64)]: Done 17797 tasks      | elapsed:  8.5min
# [Parallel(n_jobs=64)]: Done 17986 tasks      | elapsed:  8.6min
# [Parallel(n_jobs=64)]: Done 18177 tasks      | elapsed:  8.7min
# [Parallel(n_jobs=64)]: Done 18368 tasks      | elapsed:  8.8min
# [Parallel(n_jobs=64)]: Done 18561 tasks      | elapsed:  8.9min
# [Parallel(n_jobs=64)]: Done 18754 tasks      | elapsed:  8.9min
# [Parallel(n_jobs=64)]: Done 18949 tasks      | elapsed:  9.0min
# [Parallel(n_jobs=64)]: Done 19144 tasks      | elapsed:  9.1min
# [Parallel(n_jobs=64)]: Done 19341 tasks      | elapsed:  9.2min
# [Parallel(n_jobs=64)]: Done 19538 tasks      | elapsed:  9.3min
# [Parallel(n_jobs=64)]: Done 19737 tasks      | elapsed:  9.4min
# [Parallel(n_jobs=64)]: Done 19936 tasks      | elapsed:  9.5min
# [Parallel(n_jobs=64)]: Done 20137 tasks      | elapsed:  9.6min
# [Parallel(n_jobs=64)]: Done 20338 tasks      | elapsed:  9.7min
# [Parallel(n_jobs=64)]: Done 20541 tasks      | elapsed:  9.8min
# [Parallel(n_jobs=64)]: Done 20744 tasks      | elapsed:  9.9min
# [Parallel(n_jobs=64)]: Done 20949 tasks      | elapsed: 10.0min
# [Parallel(n_jobs=64)]: Done 21154 tasks      | elapsed: 10.1min
# [Parallel(n_jobs=64)]: Done 21361 tasks      | elapsed: 10.2min
# [Parallel(n_jobs=64)]: Done 21568 tasks      | elapsed: 10.3min
# [Parallel(n_jobs=64)]: Done 21777 tasks      | elapsed: 10.4min
# [Parallel(n_jobs=64)]: Done 21986 tasks      | elapsed: 10.5min
# [Parallel(n_jobs=64)]: Done 22197 tasks      | elapsed: 10.6min
# [Parallel(n_jobs=64)]: Done 22408 tasks      | elapsed: 10.7min
# [Parallel(n_jobs=64)]: Done 22621 tasks      | elapsed: 10.8min
# [Parallel(n_jobs=64)]: Done 22834 tasks      | elapsed: 10.9min
# [Parallel(n_jobs=64)]: Done 23049 tasks      | elapsed: 11.0min
# [Parallel(n_jobs=64)]: Done 23264 tasks      | elapsed: 11.1min
# [Parallel(n_jobs=64)]: Done 23481 tasks      | elapsed: 11.2min
# [Parallel(n_jobs=64)]: Done 23698 tasks      | elapsed: 11.3min
# [Parallel(n_jobs=64)]: Done 23917 tasks      | elapsed: 11.4min
# [Parallel(n_jobs=64)]: Done 24136 tasks      | elapsed: 11.5min
# [Parallel(n_jobs=64)]: Done 24357 tasks      | elapsed: 11.7min
# [Parallel(n_jobs=64)]: Done 24578 tasks      | elapsed: 11.8min
# [Parallel(n_jobs=64)]: Done 24801 tasks      | elapsed: 11.9min
# [Parallel(n_jobs=64)]: Done 25024 tasks      | elapsed: 12.0min
# [Parallel(n_jobs=64)]: Done 25249 tasks      | elapsed: 12.1min
# [Parallel(n_jobs=64)]: Done 25474 tasks      | elapsed: 12.2min
# [Parallel(n_jobs=64)]: Done 25701 tasks      | elapsed: 12.3min
# [Parallel(n_jobs=64)]: Done 25928 tasks      | elapsed: 12.4min
# [Parallel(n_jobs=64)]: Done 26157 tasks      | elapsed: 12.5min
# [Parallel(n_jobs=64)]: Done 26386 tasks      | elapsed: 12.6min
# [Parallel(n_jobs=64)]: Done 26617 tasks      | elapsed: 12.7min
# [Parallel(n_jobs=64)]: Done 26848 tasks      | elapsed: 12.9min
# [Parallel(n_jobs=64)]: Done 27081 tasks      | elapsed: 13.0min
# [Parallel(n_jobs=64)]: Done 27314 tasks      | elapsed: 13.1min
# [Parallel(n_jobs=64)]: Done 27549 tasks      | elapsed: 13.2min
# [Parallel(n_jobs=64)]: Done 27784 tasks      | elapsed: 13.3min
# [Parallel(n_jobs=64)]: Done 28021 tasks      | elapsed: 13.4min
# [Parallel(n_jobs=64)]: Done 28258 tasks      | elapsed: 13.5min
# [Parallel(n_jobs=64)]: Done 28497 tasks      | elapsed: 13.6min
# [Parallel(n_jobs=64)]: Done 28736 tasks      | elapsed: 13.8min
# [Parallel(n_jobs=64)]: Done 28977 tasks      | elapsed: 13.9min
# [Parallel(n_jobs=64)]: Done 29218 tasks      | elapsed: 14.0min
# [Parallel(n_jobs=64)]: Done 29461 tasks      | elapsed: 14.1min
# [Parallel(n_jobs=64)]: Done 29704 tasks      | elapsed: 14.2min
# [Parallel(n_jobs=64)]: Done 29949 tasks      | elapsed: 14.3min
# [Parallel(n_jobs=64)]: Done 30194 tasks      | elapsed: 14.5min
# [Parallel(n_jobs=64)]: Done 30441 tasks      | elapsed: 14.6min
# [Parallel(n_jobs=64)]: Done 30688 tasks      | elapsed: 14.7min
# [Parallel(n_jobs=64)]: Done 30937 tasks      | elapsed: 14.8min
# [Parallel(n_jobs=64)]: Done 31186 tasks      | elapsed: 14.9min
# [Parallel(n_jobs=64)]: Done 31437 tasks      | elapsed: 15.1min
# [Parallel(n_jobs=64)]: Done 31688 tasks      | elapsed: 15.2min
# [Parallel(n_jobs=64)]: Done 31941 tasks      | elapsed: 15.3min
# [Parallel(n_jobs=64)]: Done 32194 tasks      | elapsed: 15.4min
# [Parallel(n_jobs=64)]: Done 32449 tasks      | elapsed: 15.6min
# [Parallel(n_jobs=64)]: Done 32640 out of 32640 | elapsed: 15.7min finished
# double_expression: (32640, 256)
# double_logfc: (32640, 256)

# %%
for i in double_convergence:
    if i == 1.0:
        continue
    else:
        print(i)

# %%
single_logfc = np.asarray(ko_logfc)

single_a = single_logfc[subset_pairs[:, 0], :]
single_b = single_logfc[subset_pairs[:, 1], :]

expected_additive = single_a + single_b

interaction_residuals = double_logfc - expected_additive

print("double KO:", double_logfc.shape)
print("additive expectation:", expected_additive.shape)
print("interaction residuals:", interaction_residuals.shape)
# Out:
# double KO: (32640, 256)
# additive expectation: (32640, 256)
# interaction residuals: (32640, 256)

# %%
errors = interaction_residuals.ravel()

# Just in case a simulation produced zero expression and therefore
# an infinite logFC:
errors = errors[np.isfinite(errors)]

print("Number of residuals:", len(errors))
print("Mean:", errors.mean())
print("SD:", errors.std())

print("Quantiles:")
print(
    np.quantile(
        errors,
        [0, 0.001, 0.01, 0.05, 0.5, 0.95, 0.99, 0.999, 1]
    )
)
# Out:
# Number of residuals: 8355840
# Mean: 0.34773164461759887
# SD: 2.88000100792425
# Quantiles:
# [-3.91838391e+01 -1.28098850e+01 -4.39699242e+00 -5.61672827e-01
#   8.52287453e-06  1.86552995e+00  1.95697640e+01  2.63411848e+01
#   5.13327124e+01]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))

plt.hist(
    errors,
    bins=30000
)

plt.axvline(0, linewidth=1)

plt.xlim(-0.01, 0.01)

plt.xlabel("Double-KO LFC minus additive expectation")
plt.ylabel("Count")
plt.title("Small GRN: all double-KO residuals")

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))

plt.hist(
    errors,
    bins=30000
)

plt.axvline(0, linewidth=1)

plt.xlim(-0.1, 0.1)

plt.xlabel("Double-KO LFC minus additive expectation")
plt.ylabel("Count")
plt.title("Small GRNV2: all double-KO residuals")

plt.tight_layout()
plt.show()

# %%
print(pd.read_csv("../../../grn_benchmark/new_results/test_metrics.csv").to_string(index=False))

p = np.load("../../../grn_benchmark/new_results/test_predictions.npz")
test_pairs = p["pairs"]
observed = p["observed"]
mlp_predictions = p["mlp"]
ridge_predictions = p["ridge"]
additive_predictions = p["additive"]
# Out:
#    model      mse     rmse  mean_l2  standardized_rmse  mse_improvement_over_additive_pct  non_target_gene_rmse  delta_from_wt_pearson  implied_residual_pearson  implied_residual_spearman  large_residual_rmse  fraction_pairs_lower_mse_than_additive  negative_prediction_fraction
#       WT 0.032441 0.180114 2.056907           1.973425                        -244.552757              0.180068                    NaN                  0.441657                   0.178307             0.582421                                0.107414                      0.000000
# Additive 0.009415 0.097033 0.619820           1.814124                           0.000000              0.096814               0.875339                       NaN                        NaN             0.842321                                0.000000                      0.026101
#    Ridge 0.006934 0.083270 0.880718           1.788866                          26.354804              0.083110               0.886625                  0.514329                   0.124967             0.615783                                0.159804                      0.128482
#      MLP 0.004476 0.066901 0.631678           1.769753                          52.463972              0.066699               0.928622                  0.725928                   0.138041             0.463348                                0.160968                      0.110850

# %%
import pandas as pd

# Display test_metrics as a formatted Jupyter HTML table
df_metrics = pd.read_csv("../../../grn_benchmark/new_results/test_metrics.csv")
df_metrics
# Out:
#       model       mse      rmse   mean_l2  standardized_rmse  \
# 0        WT  0.032441  0.180114  2.056907           1.973425
# 1  Additive  0.009415  0.097033  0.619820           1.814124
# 2     Ridge  0.006934  0.083270  0.880718           1.788866
# 3       MLP  0.004476  0.066901  0.631678           1.769753
#
#    mse_improvement_over_additive_pct  non_target_gene_rmse  \
# 0                        -244.552757              0.180068
# 1                           0.000000              0.096814
# 2                          26.354804              0.083110
# 3                          52.463972              0.066699
#
#    delta_from_wt_pearson  implied_residual_pearson  implied_residual_spearman  \
# 0                    NaN                  0.441657                   0.178307
# 1               0.875339                       NaN                        NaN
# 2               0.886625                  0.514329                   0.124967
# 3               0.928622                  0.725928                   0.138041
#
#    large_residual_rmse  fraction_pairs_lower_mse_than_additive  \
# 0             0.582421                                0.107414
# 1             0.842321                                0.000000
# 2             0.615783                                0.159804
# 3             0.463348                                0.160968
#
#    negative_prediction_fraction
# 0                      0.000000
# 1                      0.026101
# 2                      0.128482
# 3                      0.110850

# %%
import json

with open("../../../grn_benchmark/new_results/test_results.json", "r") as f:
  data = json.load(f)
data["bootstrap"]["MLP"]["mse_improvement_pct_ci95"]
# Out:
# [50.96355320109436, 53.949317996468395]

# %% [markdown]
# # Lets train MLP on toy 256 gene GRN

# %%
n_genes = G.n
n_double = len(pairs)

# X_double[i] contains two 1s: the two genes knocked out
X_double = np.zeros((n_double, n_genes), dtype=np.float32)

rows = np.arange(n_double)
X_double[rows, pairs[:, 0]] = 1.0
X_double[rows, pairs[:, 1]] = 1.0

Y_double = np.asarray(double_expression, dtype=np.float32)

print(X_double.shape)
print(Y_double.shape)

print("Example pair:", pairs[0])
print("Non-zero entries:", np.where(X_double[0] == 1)[0])
# Out:
# (32640, 256)
# (32640, 256)
# Example pair: [0 1]
# Non-zero entries: [0 1]

# %%
rng = np.random.default_rng(42)

indices = rng.permutation(n_double)

n_test = int(0.50 * n_double)
n_val  = int(0.10 * n_double)

test_idx = indices[:n_test]
val_idx = indices[n_test:n_test + n_val]
train_idx = indices[n_test + n_val:]

print(
    len(train_idx),
    len(val_idx),
    len(test_idx)
)
# Out:
# 13056 3264 16320

# %%
X_wt = np.zeros((1, n_genes), dtype=np.float32)
Y_wt = wt_expression.reshape(1, -1).astype(np.float32)

# %%
X_single = np.eye(n_genes, dtype=np.float32)
Y_single = np.asarray(ko_expression, dtype=np.float32)

# %%
X_train = np.concatenate([
    X_wt,
    X_single,
    X_double[train_idx]
], axis=0)

Y_train = np.concatenate([
    Y_wt,
    Y_single,
    Y_double[train_idx]
], axis=0)

X_val = X_double[val_idx]
Y_val = Y_double[val_idx]

X_test = X_double[test_idx]
Y_test = Y_double[test_idx]

print("train:", X_train.shape, Y_train.shape)
print("val:  ", X_val.shape, Y_val.shape)
print("test: ", X_test.shape, Y_test.shape)
# Out:
# train: (13313, 256) (13313, 256)
# val:   (3264, 256) (3264, 256)
# test:  (16320, 256) (16320, 256)

# %%
y_mean = Y_train.mean(axis=0)
y_std = Y_train.std(axis=0)

# Avoid division by ~zero for nearly invariant genes
y_std = np.maximum(y_std, 1e-6)

Y_train_scaled = (Y_train - y_mean) / y_std
Y_val_scaled   = (Y_val   - y_mean) / y_std
Y_test_scaled  = (Y_test  - y_mean) / y_std

# %%
np.save("single_KO_expression.npy", np.asarray(ko_expression))

# %%
linear_model = nn.Linear(256, 256)

# %%
import torch
import torch.nn as nn

class PerturbationMLP(nn.Module):
    def __init__(self, n_genes=256):
        super().__init__()

        self.net = nn.Sequential(
            nn.Linear(n_genes, 512),
            nn.GELU(),

            nn.Linear(512, 512),
            nn.GELU(),

            nn.Linear(512, n_genes)
        )

    def forward(self, x):
        return self.net(x)
